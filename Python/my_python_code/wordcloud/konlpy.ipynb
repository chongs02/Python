# %%
import os
from wordcloud import WordCloud
import pandas as pd

# %%
os.chdir('D:/git_ec/R/R/R_Lecture/')

# %%
os.getcwd()
# Out:
# 'D:\\git_ec\\R\\R\\R_Lecture'

# %%
infile = 'data/oracle_alert_testdb.log'

# %%
with open(infile) as f:
    f = f.readlines()

# %%
lines = []
for line in f:
    lines.append(line)

# %%
lines
# Out:
# ['Tue Oct 30 17:43:46 2012\n',
#  'Starting ORACLE instance (normal)\n',
#  'LICENSE_MAX_SESSION = 0\n',
#  'LICENSE_SESSIONS_WARNING = 0\n',
#  'Shared memory segment for instance monitoring created\n',
#  'Picked latch-free SCN scheme 2\n',
#  'Using LOG_ARCHIVE_DEST_1 parameter default value as USE_DB_RECOVERY_FILE_DEST\n',
#  'Autotune of undo retention is turned on. \n',
#  'IMODE=BR\n',
#  'ILAT =27\n',
#  'LICENSE_MAX_USERS = 0\n',
#  'SYS auditing is disabled\n',
#  'Starting up:\n',
#  'Oracle Database 11g Enterprise Edition Release 11.2.0.2.0 - Production\n',
#  'With the Partitioning, OLAP, Data Mining and Real Application Testing options.\n',
#  'Using parameter settings in client-side pfile /app/oracle/admin/testdb/pfile/init.ora on machine localhost.localdomain\n',
#  'System parameters with non-default values:\n',
#  '  processes                = 150\n',
#  '  memory_target            = 404M\n',
# ...

# %%
from konlpy.tag import Hannanum

# %%
hannanum = Hannanum()

# %%
print(hannanum.nouns(lines))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-54-0f9c53443c11> in <module>
# ----> 1 print(hannanum.nouns(lines))
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_hannanum.py in nouns(self, phrase)
#      96         """Noun extractor."""
#      97
# ---> 98         tagged = self.pos(phrase)
#      99         return [s for s, t in tagged if t.startswith('N')]
#     100
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_hannanum.py in pos(self, phrase, ntags, flatten, join)
#      86
#      87         if ntags == 9:
# ---> 88             result = self.jhi.simplePos09(phrase)
#      89         elif ntags == 22:
#      90             result = self.jhi.simplePos22(phrase)
#
# RuntimeError: No matching overloads found for simplePos09 in find. at native\common\jp_method.cpp:127
